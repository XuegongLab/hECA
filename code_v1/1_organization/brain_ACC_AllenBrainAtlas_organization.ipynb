# %%
setwd('/stor/public/hcad/brain_ACC_AllenBrainAtlas/')
library(dplyr)
exon <- read.csv("human_ACC_2018-10-04_exon-matrix.csv", row.names = 1, check.names = FALSE)
intron <- read.csv("human_ACC_2018-10-04_intron-matrix.csv", row.names = 1, check.names = FALSE)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
mat <- exon + intron
mat[1:10, 1:10]
# Out:
#          SM-DAIFE_S81_E1-50 SM-DAIFE_S82_E1-50 SM-DAIFE_S83_E1-50
# 3.8-1.2   0                 0                  0
# 3.8-1.3   0                 0                  0
# 3.8-1.4   0                 0                  0
# 3.8-1.5   0                 0                  0
# 5-HT3C2   0                 0                  0
# A1BG      0                 0                  1
# A1BG-AS1  0                 0                  0
# A1CF      0                 0                  0
# A2M      13                 2                  0
# A2M-AS1   0                 0                  0
#          SM-DAIFE_S84_E1-50 SM-DAIFE_S85_E1-50 SM-DAIFE_S86_E1-50
# 3.8-1.2  0                  0                    0
# 3.8-1.3  0                  0                    0
# 3.8-1.4  0                  0                    0
# 3.8-1.5  0                  0                    0
# 5-HT3C2  0                  1                    0
# A1BG     0                  1                    0
# ...

# %%
genes <- read.csv("human_ACC_2018-10-04_genes-rows.csv")
genes
# Out:
#       gene        chromosome entrez_id
# 1     3.8-1.2     6             353007
# 2     3.8-1.3     6             353008
# 3     3.8-1.4     6             353009
# 4     3.8-1.5     6             353010
# 5     5-HT3C2     3             389180
# 6     A1BG        19                 1
# 7     A1BG-AS1    19            503538
# 8     A1CF        10             29974
# 9     A2M         12                 2
# 10    A2M-AS1     12            144571
# 11    A2ML1       12            144568
# 12    A2MP1       12                 3
# 13    A3GALT2     1             127550
# 14    A4GALT      22             53947
# 15    A4GNT       3              51146
# 16    AA06        17         100506677
# 17    AAAS        12              8086
# 18    AACS        12             65985
# 19    AACSP1      5             729522
# 20    AADAC       3                 13
# 21    AADACL2     3             344752
# 22    AADACL2-AS1 3          101928142
# 23    AADACL3     1             126767
# ...

# %%
write.table(mat, file = "brain_ACC_AllenBrianAtlas_expression.tsv", sep = "\t", quote = FALSE)
