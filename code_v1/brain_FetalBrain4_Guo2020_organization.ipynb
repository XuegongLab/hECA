# %%
setwd('/home/xixi/HCL')
meta <- read.csv('HCL_Fig1_cell_Info.csv', header = TRUE)
meta[1:10, ]
# Out:
#    cellnames                         sample       cluster stage batch
# 1  AdultAdipose_1.TATGTAACACCCGCAGGA AdultAdipose 2       Adult AdultAdipose1
# 2  AdultAdipose_1.CTCGCAAATAAACATCCC AdultAdipose 2       Adult AdultAdipose1
# 3  AdultAdipose_1.CGAGTATCGTAATACTTC AdultAdipose 2       Adult AdultAdipose1
# 4  AdultAdipose_1.CTCGCAGCGAATCGGCAG AdultAdipose 2       Adult AdultAdipose1
# 5  AdultAdipose_1.ACGTTGATCAACAGATGG AdultAdipose 2       Adult AdultAdipose1
# 6  AdultAdipose_1.GCGAATGCTGTGACAATA AdultAdipose 2       Adult AdultAdipose1
# 7  AdultAdipose_1.CTCGCAACCTGAGTGGTA AdultAdipose 2       Adult AdultAdipose1
# 8  AdultAdipose_1.TGATCAACGAGCGCAGGA AdultAdipose 2       Adult AdultAdipose1
# 9  AdultAdipose_1.GAACGCTTCCGCAGTTTA AdultAdipose 2       Adult AdultAdipose1
# 10 AdultAdipose_1.CGAGTAAAAGTTTGCAAT AdultAdipose 2       Adult AdultAdipose1
#    donor   celltype
# 1  Donor20 Macrophage
# 2  Donor20 Macrophage
# 3  Donor20 Macrophage
# 4  Donor20 Macrophage
# ...

# %%
matrix <- read.table('dge_rmbatch_data/Fetal-Brain4_rmbatchdge.txt', check.names = FALSE, header = TRUE, sep = ',')
matrix <- cbind(cell_ID = row.names(matrix), matrix)
dim(matrix)
matrix[1:10, 1:10]
# Out:
# [1] 22624  3939
#          cell_ID  FetalBrain_4.CTCGCAGCGTCCATGGCG
# A1BG     A1BG     0
# A1BG-AS1 A1BG-AS1 0
# A2M      A2M      0
# A2M-AS1  A2M-AS1  0
# A2MP1    A2MP1    0
# A4GALT   A4GALT   0
# AAAS     AAAS     0
# AACS     AACS     0
# AADACP1  AADACP1  0
# AADAT    AADAT    0
#          FetalBrain_4.GAATTAGATCTTCTGTGT FetalBrain_4.CTCCATTAGAGAGTCGGT
# A1BG     1                               0
# A1BG-AS1 0                               0
# A2M      0                               0
# A2M-AS1  0                               0
# A2MP1    0                               0
# A4GALT   0                               0
# AAAS     0                               0
# AACS     0                               0
# AADACP1  0                               0
# AADAT    0                               0
#          FetalBrain_4.CCGCTATAGAGAGCAGGA FetalBrain_4.TTCATAAGGGTCGCCCTC
# A1BG     0                               0
# A1BG-AS1 0                               0
# ...

# %%
write.table(matrix, file = '/stor/public/hcad/brain_FetalBrain4_Guo2020/brain_FetalBrain4_Guo2020_expression.tsv', 
           sep = '\t', quote = FALSE, row.names = FALSE)

# %%
cell_ID <- colnames(matrix)[-1]
meta_this <- meta[as.character(meta$batch)=='FetalBrain4', ]
dim(meta_this)
meta_this
# Out:
# [1] 3920    7
#        cellnames                       sample     cluster stage batch
# 286908 FetalBrain_4.GCAGGAAGGACTATACAG FetalBrain 11      Fetus FetalBrain4
# 286909 FetalBrain_4.ATACAGAGGACTAAAGTT FetalBrain 11      Fetus FetalBrain4
# 286910 FetalBrain_4.CTCCATAAAGTTGTCGGT FetalBrain 11      Fetus FetalBrain4
# 286911 FetalBrain_4.GCAGGAATACAGTTGGAC FetalBrain 11      Fetus FetalBrain4
# 286912 FetalBrain_4.ATTTGCAGATGGTCGTAA FetalBrain 11      Fetus FetalBrain4
# 286913 FetalBrain_4.CCATCTCATGATATTTGC FetalBrain 11      Fetus FetalBrain4
# 286914 FetalBrain_4.GAATTAAATAAAGCTGTG FetalBrain 11      Fetus FetalBrain4
# 286915 FetalBrain_4.CTGTGTCAAAGTTGAAGC FetalBrain 11      Fetus FetalBrain4
# 286916 FetalBrain_4.GGACATCATCCCTGAAGC FetalBrain 11      Fetus FetalBrain4
# 286917 FetalBrain_4.AGGACTTGATCACTGTGT FetalBrain 11      Fetus FetalBrain4
# 286918 FetalBrain_4.ACACCCACCTGATTCATA FetalBrain 11      Fetus FetalBrain4
# ...

# %%
cell_cluster = rep("NA", length(cell_ID))
for (i in 1:length(cell_ID)){
    for (j in 1:dim(meta_this)[1]){
        if (cell_ID[i] == as.character(meta_this$cellnames[j])){
            cell_cluster[i] = as.character(meta_this$celltype[j])
            break
        }
    }
}
unlist(cell_cluster)
# Out:
#    [1] "Fetal neuron"
#    [2] "Fetal endocrine cell"
#    [3] "Fetal neuron"
#    [4] "Fetal neuron"
#    [5] "NA"
#    [6] "Fetal mesenchymal progenitor"
#    [7] "Macrophage"
#    [8] "Fetal neuron"
#    [9] "Fetal neuron"
#   [10] "Fetal neuron"
#   [11] "Endothelial cell"
#   [12] "Fetal neuron"
#   [13] "Macrophage"
#   [14] "Fetal neuron"
#   [15] "Macrophage"
#   [16] "Fetal neuron"
#   [17] "Erythroid cell"
#   [18] "Fetal neuron"
#   [19] "Fetal neuron"
#   [20] "Fetal neuron"
#   [21] "Fetal neuron"
#   [22] "Fetal endocrine cell"
#   [23] "Fetal neuron"
#   [24] "Macrophage"
#   [25] "Fetal neuron"
#   [26] "Fetal neuron"
#   [27] "Fetal neuron"
#   [28] "Fetal mesenchymal progenitor"
#   [29] "Fetal neuron"
#   [30] "Fetal neuron"
#   [31] "Fetal neuron"
#   [32] "Macrophage"
#   [33] "Fetal neuron"
#   [34] "Fetal neuron"
#   [35] "Fetal mesenchymal progenitor"
#   [36] "Fetal mesenchymal progenitor"
#   [37] "Macrophage"
#   [38] "Macrophage"
#   [39] "Fetal neuron"
# ...

# %%
annotation = cbind(cell_ID = cell_ID, cell_cluster = cell_cluster)
annotation
# Out:
#       cell_ID                         cell_cluster
#  [1,] FetalBrain_4.CTCGCAGCGTCCATGGCG Fetal neuron
#  [2,] FetalBrain_4.GAATTAGATCTTCTGTGT Fetal endocrine cell
#  [3,] FetalBrain_4.CTCCATTAGAGAGTCGGT Fetal neuron
#  [4,] FetalBrain_4.CCGCTATAGAGAGCAGGA Fetal neuron
#  [5,] FetalBrain_4.TTCATAAGGGTCGCCCTC NA
#  [6,] FetalBrain_4.ATTCCAAGTTTAATTCCA Fetal mesenchymal progenitor
#  [7,] FetalBrain_4.ATGGCGGCCCTCATACAG Macrophage
#  [8,] FetalBrain_4.GCAGGAAGGACTATACAG Fetal neuron
#  [9,] FetalBrain_4.CTGTGTTGATCAAAAGTT Fetal neuron
# [10,] FetalBrain_4.ATACAGAGGACTAAAGTT Fetal neuron
# [11,] FetalBrain_4.CGCTTGTTAACTTTCATA Endothelial cell
# [12,] FetalBrain_4.CTCCATAAAGTTGTCGGT Fetal neuron
# [13,] FetalBrain_4.GAATTACCTAGAGCGTCC Macrophage
# [14,] FetalBrain_4.GCAGGAATACAGTTGGAC Fetal neuron
# [15,] FetalBrain_4.TATGTAAGTCGTCTTCTG Macrophage
# [16,] FetalBrain_4.AGTCGTAAAGTTATACAG Fetal neuron
# [17,] FetalBrain_4.GACACTCCTTTCGCCCTC Erythroid cell
# ...

# %%
write.table(annotation, file = '/stor/public/hcad/brain_FetalBrain4_Guo2020/brain_FetalBrain4_Guo2020_annotation.tsv', 
           sep = '\t', quote = FALSE, row.names = FALSE)

# %%
organ <- rep("brain", length(cell_ID))
region <- rep(as.character(meta_this$sample)[1], length(cell_ID))
subregion <- region
sample_status <- rep('normal', length(cell_ID))
donor_ID <- rep(as.character(meta_this$donor)[1], length(cell_ID))
donor_gender <- rep('female', length(cell_ID))
donor_age <- rep('11 week old', length(cell_ID))
metadata <- cbind(organ, region, subregion, sample_status, cell_ID, donor_ID, donor_gender, donor_age)
metadata
# Out:
#       organ region     subregion  sample_status cell_ID
#  [1,] brain FetalBrain FetalBrain normal        FetalBrain_4.CTCGCAGCGTCCATGGCG
#  [2,] brain FetalBrain FetalBrain normal        FetalBrain_4.GAATTAGATCTTCTGTGT
#  [3,] brain FetalBrain FetalBrain normal        FetalBrain_4.CTCCATTAGAGAGTCGGT
#  [4,] brain FetalBrain FetalBrain normal        FetalBrain_4.CCGCTATAGAGAGCAGGA
#  [5,] brain FetalBrain FetalBrain normal        FetalBrain_4.TTCATAAGGGTCGCCCTC
#  [6,] brain FetalBrain FetalBrain normal        FetalBrain_4.ATTCCAAGTTTAATTCCA
#  [7,] brain FetalBrain FetalBrain normal        FetalBrain_4.ATGGCGGCCCTCATACAG
#  [8,] brain FetalBrain FetalBrain normal        FetalBrain_4.GCAGGAAGGACTATACAG
#  [9,] brain FetalBrain FetalBrain normal        FetalBrain_4.CTGTGTTGATCAAAAGTT
# [10,] brain FetalBrain FetalBrain normal        FetalBrain_4.ATACAGAGGACTAAAGTT
# [11,] brain FetalBrain FetalBrain normal        FetalBrain_4.CGCTTGTTAACTTTCATA
# ...

# %%
write.table(metadata, file = '/stor/public/hcad/brain_FetalBrain4_Guo2020/brain_FetalBrain4_Guo2020_metadata.tsv', 
           sep = '\t', quote = FALSE, row.names = FALSE)
